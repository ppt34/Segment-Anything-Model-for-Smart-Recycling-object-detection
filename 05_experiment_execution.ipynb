# %% [markdown]
# # Example experiment execution

# %% [markdown]
# ## Imports

# %%
# %cd -q experiment_lib
# !python _notebook2script.py --allFiles -q
from exp.GodClass import GodClass
# %cd -q ..

# %% [markdown]
# ## Setup

# %%
god = GodClass(config_py='experiments/example_experiment_config.py')

# %%
god.print_x_mean_and_std()
god.print_class_counts()
god.show_train_images()
god.show_val_images()
# Out:
# 'x_mean': [0.0353, 0.0244, 0.0175],
# 'x_std': [1.0377, 1.0282, 1.0152],
# 'train_class_counts': [63, 63],
# 'val_class_counts': [28, 28]

# %% [markdown]
# ## Run

# %%
god.run_episodes(5)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
#  ===== Episode Nr 1 =====
# Output()
# Multi Episode Results at Episode 1:
#
#   val_accuracy:
#     best_epoch_mean: 0.875
#     best_epoch_mean_nr: 7
#     best_epoch_mean_std: nan
#     best_epoch_mean_values: [0.875]
#
#  ===== Episode Nr 2 =====
# Output()
# Multi Episode Results at Episode 2:
#
#   val_accuracy:
#     best_epoch_mean: 0.82143
#     best_epoch_mean_nr: 4
#     best_epoch_mean_std: 0.05051
#     best_epoch_mean_values: [0.85714, 0.78571]
#
#  ===== Episode Nr 3 =====
# Output()
# Multi Episode Results at Episode 3:
#
#   val_accuracy:
#     best_epoch_mean: 0.82143
#     best_epoch_mean_nr: 3
#     best_epoch_mean_std: 0.01786
#     best_epoch_mean_values: [0.80357, 0.82143, 0.83929]
#
#  ===== Episode Nr 4 =====
# Output()
# Multi Episode Results at Episode 4:
#
#   val_accuracy:
#     best_epoch_mean: 0.80804
#     best_epoch_mean_nr: 3
#     best_epoch_mean_std: 0.0305
# ...

# %% [markdown]
# ## Save results

# %%
god.save_results(note='example experiment run')
